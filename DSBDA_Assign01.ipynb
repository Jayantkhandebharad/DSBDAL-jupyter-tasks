# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Load the dataset into pandas data frame

# %%
df= pd.read_csv('melb_data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/jayu/Downloads/dbsdl/DSBDA_Assign01.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/jayu/Downloads/dbsdl/DSBDA_Assign01.ipynb#ch0000002?line=0'>1</a> df= pd.read_csv('melb_data.csv')
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///home/jayu/.local/lib/python3.10/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///home/jayu/.local/lib/python3.10/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///home/jayu/.local/lib/python3.10/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
# ...

# %%
df.head()
# Out:
#        Suburb           Address  Rooms Type    Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000     VB  Nelson
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03-12-2016       2.5      3067  ...         1  1.0       202           NaN
# 1  04-02-2016       2.5      3067  ...         1  0.0       156          79.0
# 2  04-03-2017       2.5      3067  ...         2  0.0       134         150.0
# 3  04-03-2017       2.5      3067  ...         2  1.0        94           NaN
# 4  04-06-2016       2.5      3067  ...         1  2.0       120         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %% [markdown]
# Data PreProcessing

# %%
df.tail(6)
# Out:
#               Suburb        Address  Rooms Type    Price Method   SellerG  \
# 13574    Westmeadows     9 Black St      3    h   582000      S       Red
# 13575  Wheelers Hill   12 Strada Cr      4    h  1245000      S     Barry
# 13576   Williamstown  77 Merrett Dr      3    h  1031000     SP  Williams
# 13577   Williamstown    83 Power St      3    h  1170000      S     Raine
# 13578   Williamstown   96 Verdon St      4    h  2500000     PI   Sweeney
# 13579     Yarraville     6 Agnes St      4    h  1285000     SP   Village
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 13574  26-08-2017      16.5      3049  ...         2  2.0       256
# 13575  26-08-2017      16.7      3150  ...         2  2.0       652
# 13576  26-08-2017       6.8      3016  ...         2  2.0       333
# 13577  26-08-2017       6.8      3016  ...         2  4.0       436
# 13578  26-08-2017       6.8      3016  ...         1  5.0       866
# ...

# %%
 #prints summary of dataframe i.e index dtypecolumn non-null values etc
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  int64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  int64
#  10  Bedroom2       13580 non-null  int64
#  11  Bathroom       13580 non-null  int64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  int64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
# ...

# %%
df.size
# Out:
# 285180

# %%
df.shape
# Out:
# (13580, 21)

# %%
df.ndim
# Out:
# 2

# %%
#Returns statitics of numerical data
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
df.isnull()   #checking for null values
# Out:
#        Suburb  Address  Rooms   Type  Price  Method  SellerG   Date  Distance  \
# 0       False    False  False  False  False   False    False  False     False
# 1       False    False  False  False  False   False    False  False     False
# 2       False    False  False  False  False   False    False  False     False
# 3       False    False  False  False  False   False    False  False     False
# 4       False    False  False  False  False   False    False  False     False
# ...       ...      ...    ...    ...    ...     ...      ...    ...       ...
# 13575   False    False  False  False  False   False    False  False     False
# 13576   False    False  False  False  False   False    False  False     False
# 13577   False    False  False  False  False   False    False  False     False
# 13578   False    False  False  False  False   False    False  False     False
# 13579   False    False  False  False  False   False    False  False     False
#
# ...

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
df["BuildingArea"] = df["BuildingArea"].fillna(df["BuildingArea"].mode()[0])

# %%
df["Car"] = df["Car"].fillna(df["Car"].mean())

# %%
df["YearBuilt"] = df["YearBuilt"].fillna(df["YearBuilt"].mean())

# %%
df["CouncilArea"].fillna("Not given", inplace= True)

# %%
df.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %% [markdown]
# Data Formatting And Data Normalization

# %%
df.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price              int64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode           int64
# Bedroom2           int64
# Bathroom           int64
# Car              float64
# Landsize           int64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount      int64
# dtype: object

# %%
df["YearBuilt"] = df["YearBuilt"].astype('int')

# %%
df.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price              int64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode           int64
# Bedroom2           int64
# Bathroom           int64
# Car              float64
# Landsize           int64
# BuildingArea     float64
# YearBuilt          int32
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount      int64
# dtype: object

# %%
df1=df.copy()

# %%
df1['Price']=np.sqrt(df1['Price'])

# %%
df1.head()
# Out:
#        Suburb           Address  Rooms Type     Price  Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  0.405518       1  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  0.339116       1  Biggin
# 2  Abbotsford      5 Charles St      3    h  0.403457       3  Biggin
# 3  Abbotsford  40 Federation La      3    h  0.307318       0  Biggin
# 4  Abbotsford       55a Park St      4    h  0.421637       4  Nelson
#
#          Date  Distance  Postcode  ...  BuildingArea  YearBuilt  CouncilArea  \
# 0  03-12-2016       2.5      3067  ...           NaN        NaN        Yarra
# 1  04-02-2016       2.5      3067  ...          79.0     1900.0        Yarra
# 2  04-03-2017       2.5      3067  ...         150.0     1900.0        Yarra
# 3  04-03-2017       2.5      3067  ...           NaN        NaN        Yarra
# 4  04-06-2016       2.5      3067  ...         142.0     2014.0        Yarra
#
#    Lattitude  Longtitude             Regionname Propertycount   h   t   u
# ...

# %% [markdown]
# Categorical Variables to numeric variables

# %%
df.head()
# Out:
#        Suburb           Address  Rooms Type    Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000     VB  Nelson
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03-12-2016       2.5      3067  ...         1  1.0       202         120.0
# 1  04-02-2016       2.5      3067  ...         1  0.0       156          79.0
# 2  04-03-2017       2.5      3067  ...         2  0.0       134         150.0
# 3  04-03-2017       2.5      3067  ...         2  1.0        94         120.0
# 4  04-06-2016       2.5      3067  ...         1  2.0       120         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df['Type'].unique()
# Out:
# array(['h', 'u', 't'], dtype=object)

# %%
df['Method'].unique()
# Out:
# array(['S', 'SP', 'PI', 'VB', 'SA'], dtype=object)

# %% [markdown]
# Applying one hot encoding to convert categorical data to numerical

# %%
data_add = pd.get_dummies(df['Type']).add_prefix('Type'+ '-')
df = df.drop('Type', axis=1)
df = df.join(data_add)
df
# Out:
#               Suburb           Address  Rooms    Price Method   SellerG  \
# 0         Abbotsford      85 Turner St      2  1480000      S    Biggin
# 1         Abbotsford   25 Bloomburg St      2  1035000      S    Biggin
# 2         Abbotsford      5 Charles St      3  1465000     SP    Biggin
# 3         Abbotsford  40 Federation La      3   850000     PI    Biggin
# 4         Abbotsford       55a Park St      4  1600000     VB    Nelson
# ...              ...               ...    ...      ...    ...       ...
# 13575  Wheelers Hill      12 Strada Cr      4  1245000      S     Barry
# 13576   Williamstown     77 Merrett Dr      3  1031000     SP  Williams
# 13577   Williamstown       83 Power St      3  1170000      S     Raine
# 13578   Williamstown      96 Verdon St      4  2500000     PI   Sweeney
# 13579     Yarraville        6 Agnes St      4  1285000     SP   Village
#
#              Date  Distance  Postcode  Bedroom2  ...  BuildingArea  YearBuilt  \
# ...

# %%
e=LabelEncoder()
df["Method"]=e.fit_transform(df["Method"])

# %%
df.head()
# Out:
#        Suburb           Address  Rooms Type    Price  Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000       1  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000       1  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000       3  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000       0  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000       4  Nelson
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03-12-2016       2.5      3067  ...         1  1.0       202           NaN
# 1  04-02-2016       2.5      3067  ...         1  0.0       156          79.0
# 2  04-03-2017       2.5      3067  ...         2  0.0       134         150.0
# 3  04-03-2017       2.5      3067  ...         2  1.0        94           NaN
# 4  04-06-2016       2.5      3067  ...         1  2.0       120         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
data_add=pd.get_dummies(df['Method']).add_prefix('Method'+'-')
df = df.drop('Method', axis=1)
df = df.join(data_add)
df
# Out:
#               Suburb           Address  Rooms    Price   SellerG        Date  \
# 0         Abbotsford      85 Turner St      2  1480000    Biggin  03-12-2016
# 1         Abbotsford   25 Bloomburg St      2  1035000    Biggin  04-02-2016
# 2         Abbotsford      5 Charles St      3  1465000    Biggin  04-03-2017
# 3         Abbotsford  40 Federation La      3   850000    Biggin  04-03-2017
# 4         Abbotsford       55a Park St      4  1600000    Nelson  04-06-2016
# ...              ...               ...    ...      ...       ...         ...
# 13575  Wheelers Hill      12 Strada Cr      4  1245000     Barry  26-08-2017
# 13576   Williamstown     77 Merrett Dr      3  1031000  Williams  26-08-2017
# 13577   Williamstown       83 Power St      3  1170000     Raine  26-08-2017
# 13578   Williamstown      96 Verdon St      4  2500000   Sweeney  26-08-2017
# 13579     Yarraville        6 Agnes St      4  1285000   Village  26-08-2017
#
# ...

# %%
data_add=pd.get_dummies(df["Type"].add_prefix('Type'+ '-'))
df.drop("Type",axis=1)
df = df.join(data_add)
df
# Out:
#               Suburb           Address  Rooms Type    Price  Method   SellerG  \
# 0         Abbotsford      85 Turner St      2    h  1480000       1    Biggin
# 1         Abbotsford   25 Bloomburg St      2    h  1035000       1    Biggin
# 2         Abbotsford      5 Charles St      3    h  1465000       3    Biggin
# 3         Abbotsford  40 Federation La      3    h   850000       0    Biggin
# 4         Abbotsford       55a Park St      4    h  1600000       4    Nelson
# ...              ...               ...    ...  ...      ...     ...       ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000       1     Barry
# 13576   Williamstown     77 Merrett Dr      3    h  1031000       3  Williams
# 13577   Williamstown       83 Power St      3    h  1170000       1     Raine
# 13578   Williamstown      96 Verdon St      4    h  2500000       0   Sweeney
# 13579     Yarraville        6 Agnes St      4    h  1285000       3   Village
#
# ...
